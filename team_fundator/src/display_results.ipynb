# %% [markdown]
# # Training Results Analysis

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import seaborn as sns
import notebook_utils as nu

# %% [markdown]
# ## Generate model leaderboard

# %%
runs = nu.get_filtered_runs("runs/task_1/")
df = nu.create_model_leaderboard(runs)
display(df)
# Out:
# Found 2 runs - 1 containing logs:
# ['run_54']
#        ModelType         Backbone  Epochs  TrainBestEpoch  TrainIoU  \
# Run#
# run_54    UNet++  efficientnet-b4       2               1    0.5338
#
#         TrainBIoU  TrainScore  ValBestEpoch  ValIoU  ValBIoU  ValScore
# Run#
# run_54     0.4809      0.5073             1  0.7555   0.6825     0.719

# %% [markdown]
# ## Show training curves for models

# %%
runs = nu.get_filtered_runs("runs/task_1/")
long_df = nu.create_long_result_df(runs)
sns.relplot(
    data=long_df,
    hue="Run#",
    x="epoch",
    y="value",
    col="variable",
    col_wrap=2,
    style="set",
    kind="line",
    facet_kws={
        "sharey": False,
    }
)
# Out:
# Found 2 runs - 1 containing logs:
# ['run_54']
